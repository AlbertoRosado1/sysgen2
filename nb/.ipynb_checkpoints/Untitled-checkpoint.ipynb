# %%
import fitsio
import numpy as np
import healpy as hp

# %%
dfn = "/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock0/sysnet_clean/ELG_LOP_complete_gtlimaging0.8_1.1_N/nn-weights.fits"
nn = fitsio.read(dfn)

# %%
wt = np.mean(nn['weight'],axis=1)
wt.size
# Out:
# 40723

# %%
nn['weight']
# Out:
# array([[22.0773983 , 21.92519188, 22.17485619, 23.21247101, 21.23272514],
#        [21.41446686, 21.04883957, 21.64792442, 22.64818192, 20.52216911],
#        [18.41065979, 20.58045006, 18.34729195, 24.48348808, 21.34297371],
#        ...,
#        [24.76465225, 26.63685799, 22.62573433, 28.07568932, 24.18252182],
#        [23.02844429, 23.13585091, 23.21055031, 23.66955948, 21.49689102],
#        [29.56464005, 24.84095383, 27.60092926, 28.36244202, 29.98680878]])

# %%
hpfn = "/global/homes/a/arosado/sysgen2/py/mock0/sysnet_clean/nn-weights_ELG_LOP_complete_gtlimaging0.8_1.1_NS.fits"
hpmap = hp.read_map(hpfn)

# %%
hp.mollview(hpmap,rot=260)
