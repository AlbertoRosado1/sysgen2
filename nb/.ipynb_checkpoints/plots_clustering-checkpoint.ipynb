# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import fitsio
from astropy.table import Table, vstack
import numpy as np
from pypower import CatalogFFTPower,PowerSpectrumStatistics,setup_logging
from pycorr import TwoPointCorrelationFunction
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
#setup_logging()

# %%
def get_mean_pk(pk_fns, ells=(0,2,4), remove_shotnoise=True, factor=None, return_shotnoise=False):
    ell0 = []
    ell2 = []
    ell4 = []
    snoise = []
    for fn in pk_fns:
        result = PowerSpectrumStatistics.load(fn)
        if factor is not None: result = result[:(result.shape[0] // factor) * factor:factor]
        k,poles = result(ell=ells, return_k=True, complex=False, remove_shotnoise=remove_shotnoise)
        for i,pole in enumerate(poles):
            if i==0: ell0.append(pole)
            if i==1: ell2.append(pole)
            if i==2: ell4.append(pole)
        snoise.append(result.shotnoise)
    ell0_sigma = np.std(ell0,axis=0)
    ell0 = np.mean(ell0,axis=0)

    ell2_sigma = np.std(ell2,axis=0)
    ell2 = np.mean(ell2,axis=0)

    ell4_sigma = np.std(ell4,axis=0)
    ell4 = np.mean(ell4,axis=0)
    
    pk_mean = [ell0,ell2,ell4]
    pk_sigma = [ell0_sigma,ell2_sigma,ell4_sigma]
    snoise_mean = np.mean(snoise, axis=0)
    if return_shotnoise:
        return k, pk_mean, pk_sigma, snoise_mean
    else:
        return k, pk_mean, pk_sigma

# %%
tps = [f'{t}_complete_gtlimaging' for t in ['ELG_LOP','LRG']]#,'QSO']]
tp = 'ELG_LOP_complete_gtlimaging'
mockid = 10
mockdir = f"/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock{mockid}"

survey_dir = f"/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v0.6/blinded/"
wts = ['default_FKP']#, 'noweightsys_FKP']

mock_wts = ['default', 'default_cont']
labels = [f"data"]
mocklabels =[f"mock{mockid}",f"mock{mockid}+cont"]
markers = [None, None, None, None]
regions = ['NGC','SGC','GCcomb']
mockls = ['--',':']
ls = ['-']
nran = 4

# %%
plot_dir = "plots/v0.6/pk"
if not os.path.isdir(plot_dir):
    os.makedirs(plot_dir)
    print(f"created dir: {plot_dir}")
    
xiplot_dir = "plots/v0.6/xi"
if not os.path.isdir(plot_dir):
    os.makedirs(plot_dir)
    print(f"created dir: {plot_dir}")

# %%
mydir = f"/pscratch/sd/a/arosado/catalogs/Y1/LSS/iron/LSScats/v0.4/blinded/v0.4_3d/"
survey_dir = f"/global/cfs/cdirs/desi/survey/catalogs/Y1/LSS/iron/LSScats/v0.6/blinded/"

# %% [markdown]
# # Pk

# %%
m = Table.read("/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock10/ELG_LOP_complete_gtlimaging_SGC_clustering.dat.fits")

# %%
m = Table.read("/global/cfs/cdirs/desi/survey/catalogs/Y1/mocks/SecondGenMocks/AbacusSummit/mock0/LRG_ffa_NGC_clustering.dat.fits")

# %%
import fitsio
import numpy as np
from pypower import utils

# Set cosmology to transform redshift to distance
from cosmoprimo.fiducial import DESI
distance = DESI(engine='class').comoving_radial_distance  

fn = "/global/cfs/cdirs/desi/survey/catalogs/Y1/mocks/SecondGenMocks/AbacusSummit/mock0/LRG_ffa_NGC_clustering.dat.fits"
m = fitsio.read(fn,columns=['RA','DEC','Z','WEIGHT','WEIGHT_FKP'])
#Converting coordinates
dists=distance(m['Z'])
positions=utils.sky_to_cartesian(np.array([m['RA'],m['DEC'],dists]))
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
txt = np.array(positions+[np.ones(m['WEIGHT'].size),m['WEIGHT'].value,m['WEIGHT_FKP'].value])
np.savetxt('test.dat',txt)

# %%
np.loadtxt('test.dat')
# Out:
# array([[ 2.15518379e+01,  2.21648388e+01,  2.52339535e+01, ...,
#         -3.56265442e+02, -4.87416229e+02, -3.80860291e+02],
#        [-6.17352844e+02, -5.95844910e+02, -9.32716980e+02, ...,
#          1.55592480e+03,  1.71009839e+03,  1.60412634e+03],
#        [ 8.88002991e+02,  9.03100342e+02,  5.54481689e+02, ...,
#          1.85882812e+03,  1.68446362e+03,  1.81684119e+03],
#        [ 1.00000000e+00,  1.00000000e+00,  1.00000000e+00, ...,
#          1.00000000e+00,  1.00000000e+00,  1.00000000e+00],
#        [ 1.30255155e+00,  1.14413306e+00,  1.04084786e+00, ...,
#          7.42682882e-01,  1.20275751e+00,  7.55945104e-01],
#        [ 4.02144608e-01,  4.02144608e-01,  2.59663842e-01, ...,
#          7.91633715e-01,  6.64546605e-01,  7.91633715e-01]])

# %%
nmocks = 25
factor = 5
reg = 'GCcomb'
for tp in [tps[0]]:
    # redshift bins tracer was trained on
    if tp[:3] == 'ELG':
        zrl = [(0.8,1.1),(1.1,1.6)]
    if tp[:3] == 'QSO':
        zrl = [(0.8,1.3),(1.3,2.1)]# mocks do not have ,(2.1,3.5)] 
    if tp[:3] == 'LRG':
        zrl = [(0.4,0.6),(0.6,0.8),(0.8,1.1)]  
    if tp[:3] == 'BGS':
        zrl = [(0.1,0.4)]
        
    for zl in zrl:
        #ax = plt.gca()
        zw = str(zl[0])+'_'+str(zl[1])
        zmin,zmax = zl[0],zl[1]
        print(tp,zw)
        for wt in ['default_cont','default']:
            pkfns_clean = []
            pks_clean = []
            for mockid in range(nmocks):
                mockdir = f"/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock{mockid}"
                mock_pkdir = os.path.join(mockdir,'pk')
                mock_pkfn = os.path.join(mock_pkdir, f"pkpoles_{tp}_{reg}_{zw}_{wt}_lin.npy")
                pkfns_clean.append(mock_pkfn)
                if wt=='default':
                    result = PowerSpectrumStatistics.load(mock_pkfn)
                    if factor is not None: 
                        result = result[:(result.shape[0] // factor) * factor:factor]
                    k,poles =result(return_k=True, complex=False)
                    for ic,pole in enumerate(poles):
                        plt.plot(k, k*pole, c=f"grey",alpha=0.1)
            k,pkmean,pkerr = get_mean_pk(pkfns_clean,factor=factor)
            print(k[3]-k[2])
            for i in range(3):
                if wt=='default_cont':plt.errorbar(k,k*pkmean[i],color="r")
                else: 
                    plt.errorbar(k,k*pkmean[i],yerr=k*pkerr[i],alpha=0.5,color=f"C{i}")
                    plt.plot(k,k*pkmean[i],color="k")
                #plt.errorbar(k,k*pkmean[i],alpha=0.5,color=f"C{i}")#),yerr=k*pkerr[i],alpha=0.5,color=f"C{i}")
            
        for wt in ['default_FKP']:#,'noweightsys_FKP']:
            pkdir = os.path.join(mydir,'pk')
            pkfn = os.path.join(pkdir, f"pkpoles_ELG_LOPnotqso_{reg}_{zw}_{wt}_lin.npy")
            result = PowerSpectrumStatistics.load(pkfn)
pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock{mockid}"
                mock_pkdir = os.path.join(mockdir,'pk')
                mock_pkfn = os.path.join(mock_pkdir, f"pkpoles_{tp}_{reg}_{zw}_{wt}_lin.npy")
                pkfns_clean.append(mock_pkfn)
                k,pkmean,pkerr = get_mean_pk(pkfns_clean)
            for i in range(3):
                plt.errorbar(k,k*pkmean[i],yerr=k*pkerr[i],alpha=0.5)
        plt.ylim(-400,1000)
        
        plt.show()
# Out:
# ELG_LOP_complete_gtlimaging 0.8_1.1
# ELG_LOP_complete_gtlimaging 1.1_1.6

# %%
nmocks = 25
reg = 'GCcomb'
for tp in [tps[0]]:
    # redshift bins tracer was trained on
    if tp[:3] == 'ELG':
        zrl = [(0.8,1.1),(1.1,1.6)]
    if tp[:3] == 'QSO':
        zrl = [(0.8,1.3),(1.3,2.1)]# mocks do not have ,(2.1,3.5)] 
    if tp[:3] == 'LRG':
        zrl = [(0.4,0.6),(0.6,0.8),(0.8,1.1)]  
    if tp[:3] == 'BGS':
        zrl = [(0.1,0.4)]
        
    for zl in zrl:
        pkfns_clean = []
        pks_clean = []
        #ax = plt.gca()
        zw = str(zl[0])+'_'+str(zl[1])
        zmin,zmax = zl[0],zl[1]
        print(tp,zw)
        for wt in ['default','default_cont']:
            for mockid in range(nmocks):
                mockdir = f"/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock{mockid}"
                mock_pkdir = os.path.join(mockdir,'pk')
                mock_pkfn = os.path.join(mock_pkdir, f"pkpoles_{tp}_{reg}_{zw}_{wt}_lin.npy")
                pkfns_clean.append(mock_pkfn)
                k,pkmean,pkerr = get_mean_pk(pkfns_clean,factor=None)
            for i in range(3):
                #plt.errorbar(k,k*pkmean[i],yerr=k*pkerr[i],alpha=0.5)
                plt.plot(k,k*pkmean[i])#,yerr=k*pkerr[i],alpha=0.5)
        plt.ylim(-400,1000)
        plt.xlim(0,0.1)
        plt.show()
# Out:
# ELG_LOP_complete_gtlimaging 0.8_1.1
# ELG_LOP_complete_gtlimaging 1.1_1.6

# %%
# Python Program to find the factors of a number

# This function computes the factor of the argument passed
def print_factors(x):
    print("The factors of",x,"are:")
    for i in range(1, x + 1):
        if x % i == 0:
            print(i)

num = 402

print_factors(num)
# Out:
# The factors of 402 are:
# 1
# 2
# 3
# 6
# 67
# 134
# 201
# 402

# %%
nmocks = 6
reg = 'NGC'
for tp in tps:
    pkfns_clean = []
    pks_clean = []
    # redshift bins tracer was trained on
    if tp[:3] == 'ELG':
        zrl = [(0.8,1.1),(1.1,1.6)]
    if tp[:3] == 'QSO':
        zrl = [(0.8,1.3),(1.3,2.1)]# mocks do not have ,(2.1,3.5)] 
    if tp[:3] == 'LRG':
        zrl = [(0.4,0.6),(0.6,0.8),(0.8,1.1)]  
    if tp[:3] == 'BGS':
        zrl = [(0.1,0.4)]
        
    for zl in zrl:
        ax = plt.gca()
        zw = str(zl[0])+'_'+str(zl[1])
        zmin,zmax = zl[0],zl[1]
        print(tp,zw)
        for mockid in range(nmocks):
            mockdir = f"/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock{mockid}"
            mock_pkdir = os.path.join(mockdir,'pk')
            mock_pkfn = os.path.join(mock_pkdir, f"pkpoles_{tp}_{reg}_{zw}_default_lin.npy")
            pkfns_clean.append(mock_pkfn)
            result = PowerSpectrumStatistics.load(mock_pkfn)
            k,poles =result(return_k=True, complex=False)
            #pks_clean.append(poles)
            for ic,pole in enumerate(poles):
                ax.plot(k, k*pole, alpha=0.5, c=f"C{ic}")
        #k, poles_mean, poles_sigma = get_mean_pk(pkfns_clean)
        #for ic,pole in enumerate(poles_mean):
        #    print(len(poles_mean),pole)
        #    ax.plot(k, k*pole, c=f"C{ic}")
        ax.set_title(f"{tp[:3]} Y1 {reg}, {zmin} < z < {zmax}")
        ax.set_xlabel(r'$k$ [$h/\mathrm{Mpc}$]')
        ax.set_ylabel(r'$kP(k)$ [$(\mathrm{Mpc}/h)^{2}$]')
        #ax.set_ylim((-400,1000))
        ax.legend(ncol=2)
        plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ELG_LOP_complete_gtlimaging 0.8_1.1
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ELG_LOP_complete_gtlimaging 1.1_1.6
# LRG_complete_gtlimaging 0.4_0.6
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[54], line 26
#      24 mock_pkfn = os.path.join(mock_pkdir, f"pkpoles_{tp}_{reg}_{zw}_default_lin.npy")
#      25 pkfns_clean.append(mock_pkfn)
# ---> 26 result = PowerSpectrumStatistics.load(mock_pkfn)
#      27 k,poles =result(return_k=True, complex=False)
#      28 #pks_clean.append(poles)
#
# File /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20230725-1.0.0/code/pypower/main/lib/python3.10/site-packages/pypower/utils.py:192, in BaseClass.load(cls, filename)
#     189 @classmethod
#     190 def load(cls, filename):
#     191     cls.log_info('Loading {}.'.format(filename))
# --> 192     state = np.load(filename, allow_pickle=True)[()]
#     193     new = cls.from_state(state)
#     194     return new
#
# File /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20230725-1.0.0/conda/lib/python3.10/site-packages/numpy/lib/npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock0/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy'

# %%
pkfns_clean
# Out:
# ['/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock0/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock1/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock2/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock3/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock4/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock5/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock6/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock7/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock8/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock9/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock10/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock11/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock12/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock13/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock14/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock15/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock16/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock17/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock18/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock19/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock20/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock21/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock22/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock23/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock24/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.4_0.6_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock0/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock1/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock2/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock3/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock4/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock5/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock6/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock7/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock8/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock9/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock10/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock11/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock12/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock13/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock14/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock15/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock16/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock17/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock18/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock19/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock20/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock21/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock22/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock23/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock24/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.6_0.8_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock0/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock1/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock2/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock3/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock4/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock5/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock6/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock7/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock8/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock9/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock10/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock11/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock12/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock13/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock14/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock15/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock16/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock17/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock18/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock19/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock20/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock21/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock22/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock23/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy',
#  '/pscratch/sd/a/arosado/SecondGenMocks/AbacusSummit/mock24/pk/pkpoles_LRG_complete_gtlimaging_NGC_0.8_1.1_default_lin.npy']

# %%
        for i, mock_wt in enumerate(mock_wts):
            mock_pkdir = os.path.join(mockdir,'pk')
            mock_pkfn = os.path.join(mock_pkdir, f"pkpoles_{tp}_{reg}_{zw}_{mock_wt}_lin.npy")
            #print(mock_pkfn)
            result = PowerSpectrumStatistics.load(mock_pkfn)
            k,poles =result(return_k=True, complex=False)
            for ic,pole in enumerate(poles):
                ax[iax].plot(k, k*pole, ls=mockls[i], c=f"C{ic}", marker=markers[i])

# %%
for tp in tps:
    # redshift bins tracer was trained on
    if tp[:3] == 'ELG':
        zrl = [(0.8,1.1),(1.1,1.6)]
    if tp[:3] == 'QSO':
        zrl = [(0.8,1.3),(1.3,2.1)]# mocks do not have ,(2.1,3.5)] 
    if tp[:3] == 'LRG':
        zrl = [(0.4,0.6),(0.6,0.8),(0.8,1.1)]  
    if tp[:3] == 'BGS':
        zrl = [(0.1,0.4)]
        
    pp = PdfPages(plot_dir+f'/pk_{tp[:3]}_mock{mockid}.pdf')
    for zl in zrl:
        zw = str(zl[0])+'_'+str(zl[1])
        zmin,zmax = zl[0],zl[1]
        print(tp,zw)
        fig,lax = plt.subplots(ncols=3,nrows=2,sharex=False,sharey=True,figsize=(20,12))
        #fig.subplots_adjust(hspace=0.3,wspace=0.2)
        ax = lax.flatten()

        for iax, reg in enumerate(regions):
            for ind in [0,1]:
                iax = iax + 3*ind
                # plot pk for data
                for i, wt in enumerate(wts):
                    if tp[:3] == 'ELG': tp_ = 'ELG_LOPnotqso'
                    else: tp_ = tp[:3]
                    pkdir = os.path.join(survey_dir,'pk')
                    pkfn = os.path.join(pkdir, f"pkpoles_{tp_}_{reg}_{zw}_{wt}_lin.npy")
                    result = PowerSpectrumStatistics.load(pkfn)
                    k,poles =result(return_k=True, complex=False)
                    for ic,pole in enumerate(poles):
                        ax[iax].plot(k, k*pole, ls=ls[i], c=f"C{ic}", marker=markers[i])

                # plot pk for mock
                for i, mock_wt in enumerate(mock_wts):
                    mock_pkdir = os.path.join(mockdir,'pk')
                    mock_pkfn = os.path.join(mock_pkdir, f"pkpoles_{tp}_{reg}_{zw}_{mock_wt}_lin.npy")
                    #print(mock_pkfn)
                    result = PowerSpectrumStatistics.load(mock_pkfn)
                    k,poles =result(return_k=True, complex=False)
                    for ic,pole in enumerate(poles):
                        ax[iax].plot(k, k*pole, ls=mockls[i], c=f"C{ic}", marker=markers[i])

                for i,wt in enumerate(wts):
                    ax[iax].plot([],[],ls=ls[i], c='k',label=labels[i], marker=markers[i])
                for i,wt in enumerate(mock_wts):
                    ax[iax].plot([],[],ls=mockls[i], c='k',label=mocklabels[i], marker=markers[i])
                for i,ell in enumerate([0,2,4]):
                    ax[iax].plot([],[],ls='-', c=f'C{i}', label=f"$\ell$={ell}")
                ax[iax].grid(True)
                ax[iax].set_title(f"{tp[:3]} Y1 {reg}, {zmin} < z < {zmax}")
                ax[iax].set_xlabel(r'$k$ [$h/\mathrm{Mpc}$]')
                ax[iax].set_ylabel(r'$kP(k)$ [$(\mathrm{Mpc}/h)^{2}$]')
                ax[iax].set_ylim((-400,1000))
                ax[iax].legend(ncol=2)
                if iax>=3: ax[iax].set_xlim((-0.001,0.05))

        pp.savefig()
        plt.show()
        print('\n')
    pp.close()
